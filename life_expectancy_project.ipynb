# %% [markdown]
# <a href="https://colab.research.google.com/github/BD-David1108/AI_Projects/blob/main/life_expectancy_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
#Loading and checking data
dataset = pd.read_csv('/content/drive/MyDrive/data/life_expectancy.csv')
print(dataset.head())
print(dataset.describe())
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
#Dropping column
dataset.drop(['Country'], axis=1)
# Out:
#       Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0     2015  Developing            263.0             62     0.01
# 1     2014  Developing            271.0             64     0.01
# 2     2013  Developing            268.0             66     0.01
# 3     2012  Developing            272.0             69     0.01
# 4     2011  Developing            275.0             71     0.01
# ...    ...         ...              ...            ...      ...
# 2933  2004  Developing            723.0             27     4.36
# 2934  2003  Developing            715.0             26     4.06
# 2935  2002  Developing             73.0             25     4.43
# 2936  2001  Developing            686.0             25     1.72
# 2937  2000  Developing            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# 0                  71.279624         65.0      1154   19.1
# 1                  73.523582         62.0       492   18.6
# ...

# %%
#Label and feature split
labels = dataset.iloc[:,-1]
features = dataset.iloc[:, 0:-1]

# %%
#Preprocessing
features = pd.get_dummies(dataset)

# %%
#Train and test split
features_train, features_test,labels_train, labels_test = train_test_split(features, labels, test_size=0.15, random_state = 25)

# %%
#Fit and standardize numerical features instead of normalizer bcoz I don't know LOL
numerical_features = features.select_dtypes(include=['float64', 'int64'])
numerical_columns = numerical_features.columns
ct = ColumnTransformer([("Numeric ", StandardScaler(), numerical_columns)], remainder='passthrough')
features_train_scaled = ct.fit_transform(features_train)
features_test_scaled = ct.transform(features_test)

# %%
#Building the model
my_model = Sequential()
input = InputLayer(input_shape = (features.shape[1],))
my_model.add(input)
my_model.add(Dense(64, activation='relu'))
my_model.add(Dense(1))
print(my_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                13824
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 13889 (54.25 KB)
# Trainable params: 13889 (54.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#Initializing optimizer and compiling model
opt = Adam(learning_rate = 0.01)
my_model.compile(loss='mse', metrics='mae', optimizer=opt)

# %%
#Model fit and eval
my_model.fit(features_train, labels_train, epochs=40, batch_size=1, verbose=1)
res_mse, res_mae = my_model.evaluate(features_test, labels_test, verbose=0)
print("RMSE: ", res_mse)
print("RMAE: ", res_mae)
# Out:
# Epoch 1/40
# 2497/2497 [==============================] - 14s 5ms/step - loss: 964777148416.0000 - mae: 106133.1875
# Epoch 2/40
# 2497/2497 [==============================] - 6s 3ms/step - loss: 22077406.0000 - mae: 502.2891
# Epoch 3/40
# 2497/2497 [==============================] - 5s 2ms/step - loss: 14736.3682 - mae: 76.8821
# Epoch 4/40
# 2497/2497 [==============================] - 5s 2ms/step - loss: 24081.3516 - mae: 80.8721
# Epoch 5/40
# 2497/2497 [==============================] - 4s 2ms/step - loss: 13117.3096 - mae: 78.4651
# Epoch 6/40
# 2497/2497 [==============================] - 4s 2ms/step - loss: 9622.0625 - mae: 75.2872
# Epoch 7/40
# 2497/2497 [==============================] - 6s 2ms/step - loss: 6174.2197 - mae: 68.1190
# Epoch 8/40
# 2497/2497 [==============================] - 4s 2ms/step - loss: 4612.4243 - mae: 60.5542
# Epoch 9/40
# 2497/2497 [==============================] - 4s 2ms/step - loss: 2591.6992 - mae: 48.2829
# Epoch 10/40
# ...
